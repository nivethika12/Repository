# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nivethika Rajasekaram** <br> Iam a Credit Analyst

# %% [markdown]
# *I am interested in data science because it is a challenging job*

# %% [markdown]
# ### Calculating the total

# %%
5+5+1
# Out:
# 11

# %% [markdown]
# > weather update
#
#
# ```python
# def staySafe(HeavyRain)
#   if not home:
#     return home
# ```
# please visit [accuweather](https://www.accuweather.com/) to weather update
#
# Following are the rain fall areas:
# 1. Main city colombo
# 2. Main city Kandy
# 3. Main city Anuradhapura
